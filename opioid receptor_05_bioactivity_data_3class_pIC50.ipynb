# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target
target_query = target.search('CHEMBL233')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#   cross_references      organism  \
# 0               []  Homo sapiens
# 1               []  Homo sapiens
# 2               []  Homo sapiens
# 3               []  Homo sapiens
# 4               []  Homo sapiens
# 5               []  Homo sapiens
# 6               []  Homo sapiens
#
#                                          pref_name  score  species_group_flag  \
# 0                               Mu opioid receptor   12.0               False
# 1                  CCR5/mu opioid receptor complex    8.0               False
# 2                     Opioid receptors; mu & delta    7.0               False
# 3                     Opioid receptors; mu & kappa    7.0               False
# 4  Mu opioid receptor/Alpha-2A adrenergic receptor    7.0               False
# 5   Cannabinoid receptor 1/Mu-type opioid receptor    7.0               False
# 6                 Opioid receptors; mu/kappa/delta    6.0               False
#
#   target_chembl_id                                  target_components  \
# 0        CHEMBL233  [{'accession': 'P35372', 'component_descriptio...
# 1    CHEMBL3301384  [{'accession': 'P51681', 'component_descriptio...
# 2    CHEMBL2095149  [{'accession': 'P41143', 'component_descriptio...
# 3    CHEMBL2095156  [{'accession': 'P41145', 'component_descriptio...
# 4    CHEMBL3883321  [{'accession': 'P08913', 'component_descriptio...
# 5    CHEMBL3885538  [{'accession': 'P21554', 'component_descriptio...
# 6    CHEMBL2095181  [{'accession': 'P41145', 'component_descriptio...
#
#          target_type  tax_id
# 0     SINGLE PROTEIN    9606
# 1    PROTEIN COMPLEX    9606
# 2  SELECTIVITY GROUP    9606
# 3  SELECTIVITY GROUP    9606
# 4    PROTEIN COMPLEX    9606
# 5    PROTEIN COMPLEX    9606
# 6     PROTEIN FAMILY    9606

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL233'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
print(len(res))
# Out:
# 2452

# %%
df.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None        32544                  []
# 1        None             None        33756                  []
# 2        None             None        38634                  []
# 3        None             None        38643                  []
# 4        None             None        39754                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL749749  Binding affinity on cloned opioid receptor mu ...
# 1    CHEMBL749749  Binding affinity on cloned opioid receptor mu ...
# 2    CHEMBL749749  Binding affinity on cloned opioid receptor mu ...
# 3    CHEMBL749749  Binding affinity on cloned opioid receptor mu ...
# 4    CHEMBL749749  Binding affinity on cloned opioid receptor mu ...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
#
#   target_organism    target_pref_name target_tax_id text_value  toid  type  \
# 0    Homo sapiens  Mu opioid receptor          9606       None  None  IC50
# 1    Homo sapiens  Mu opioid receptor          9606       None  None  IC50
# 2    Homo sapiens  Mu opioid receptor          9606       None  None  IC50
# 3    Homo sapiens  Mu opioid receptor          9606       None  None  IC50
# 4    Homo sapiens  Mu opioid receptor          9606       None  None  IC50
#
#   units    uo_units upper_value    value
# 0    nM  UO_0000065        None   5250.0
# 1    nM  UO_0000065        None   3480.0
# 2    nM  UO_0000065        None    320.0
# 3    nM  UO_0000065        None   4130.0
# 4    nM  UO_0000065        None  10000.0
#
# [5 rows x 46 columns]

# %%
df.tail()
# Out:
#                                             action_type activity_comment  \
# 2447  {'action_type': 'ANTAGONIST', 'description': '...             None
# 2448  {'action_type': 'ANTAGONIST', 'description': '...             None
# 2449  {'action_type': 'ANTAGONIST', 'description': '...             None
# 2450                                               None             None
# 2451                                               None             None
#
#       activity_id                                activity_properties  \
# 2447     25631924                                                 []
# 2448     25631925                                                 []
# 2449     25631926                                                 []
# 2450     25778419  [{'comments': None, 'relation': '=', 'result_f...
# 2451     25787567  [{'comments': None, 'relation': None, 'result_...
#
#      assay_chembl_id                                  assay_description  \
# 2447   CHEMBL5365899  Antagonist activity at human mu opioid recepto...
# 2448   CHEMBL5365899  Antagonist activity at human mu opioid recepto...
# 2449   CHEMBL5365899  Antagonist activity at human mu opioid recepto...
# 2450   CHEMBL5465602  Selectivity interaction (BET inhibitor selecti...
# 2451   CHEMBL5474455  Selectivity interaction (Opioid Mu GTPgS agoni...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 2447          F                    None                   None  BAO_0000190
# 2448          F                    None                   None  BAO_0000190
# 2449          F                    None                   None  BAO_0000190
# 2450          B                    None                   None  BAO_0000190
# 2451          B                    None                   None  BAO_0000190
#
#       ... target_organism    target_pref_name target_tax_id text_value  toid  \
# 2447  ...    Homo sapiens  Mu opioid receptor          9606       None  None
# 2448  ...    Homo sapiens  Mu opioid receptor          9606       None  None
# 2449  ...    Homo sapiens  Mu opioid receptor          9606       None  None
# 2450  ...    Homo sapiens  Mu opioid receptor          9606       None  None
# 2451  ...    Homo sapiens  Mu opioid receptor          9606       None  None
#
#       type units    uo_units upper_value  value
# 2447  IC50    nM  UO_0000065        None  210.0
# 2448  IC50    nM  UO_0000065        None  110.0
# 2449  IC50    nM  UO_0000065        None   29.0
# 2450  IC50    uM  UO_0000065        None  100.0
# 2451  IC50    uM  UO_0000065        None   30.0
#
# [5 rows x 46 columns]

# %%
df.info()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2452 entries, 0 to 2451
# Data columns (total 46 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   action_type                66 non-null     object
#  1   activity_comment           1181 non-null   object
#  2   activity_id                2452 non-null   int64
#  3   activity_properties        2452 non-null   object
#  4   assay_chembl_id            2452 non-null   object
#  5   assay_description          2452 non-null   object
#  6   assay_type                 2452 non-null   object
#  7   assay_variant_accession    0 non-null      object
#  8   assay_variant_mutation     0 non-null      object
#  9   bao_endpoint               2452 non-null   object
#  10  bao_format                 2452 non-null   object
#  11  bao_label                  2452 non-null   object
#  12  canonical_smiles           2419 non-null   object
#  13  data_validity_comment      7 non-null      object
#  14  data_validity_description  7 non-null      object
#  15  document_chembl_id         2452 non-null   object
#  16  document_journal           1339 non-null   object
#  17  document_year              1395 non-null   float64
#  18  ligand_efficiency          674 non-null    object
#  19  molecule_chembl_id         2452 non-null   object
#  20  molecule_pref_name         982 non-null    object
#  21  parent_molecule_chembl_id  2452 non-null   object
#  22  pchembl_value              1187 non-null   object
#  23  potential_duplicate        2452 non-null   int64
#  24  qudt_units                 1531 non-null   object
#  25  record_id                  2452 non-null   int64
#  26  relation                   1496 non-null   object
#  27  src_id                     2452 non-null   int64
#  28  standard_flag              2452 non-null   int64
#  29  standard_relation          1496 non-null   object
#  30  standard_text_value        0 non-null      object
#  31  standard_type              2452 non-null   object
#  32  standard_units             1531 non-null   object
#  33  standard_upper_value       0 non-null      object
#  34  standard_value             1509 non-null   object
#  35  target_chembl_id           2452 non-null   object
#  36  target_organism            2452 non-null   object
#  37  target_pref_name           2452 non-null   object
#  38  target_tax_id              2452 non-null   object
#  39  text_value                 0 non-null      object
#  40  toid                       0 non-null      object
#  41  type                       2452 non-null   object
#  42  units                      1469 non-null   object
#  43  uo_units                   1531 non-null   object
#  44  upper_value                7 non-null      object
#  45  value                      1509 non-null   object
# dtypes: float64(1), int64(5), object(40)
# memory usage: 881.3+ KB
# Index(['action_type', 'activity_comment', 'activity_id', 'activity_properties',
#        'assay_chembl_id', 'assay_description', 'assay_type',
#        'assay_variant_accession', 'assay_variant_mutation', 'bao_endpoint',
#        'bao_format', 'bao_label', 'canonical_smiles', 'data_validity_comment',
#        'data_validity_description', 'document_chembl_id', 'document_journal',
#        'document_year', 'ligand_efficiency', 'molecule_chembl_id',
#        'molecule_pref_name', 'parent_molecule_chembl_id', 'pchembl_value',
#        'potential_duplicate', 'qudt_units', 'record_id', 'relation', 'src_id',
#        'standard_flag', 'standard_relation', 'standard_text_value',
#        'standard_type', 'standard_units', 'standard_upper_value',
#        'standard_value', 'target_chembl_id', 'target_organism',
#        'target_pref_name', 'target_tax_id', 'text_value', 'toid', 'type',
#        'units', 'uo_units', 'upper_value', 'value'],
#       dtype='object')

# %%
df2 = df.dropna(subset=["standard_value", "canonical_smiles"])

# %%
df2
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 2447  {'action_type': 'ANTAGONIST', 'description': '...             None
# 2448  {'action_type': 'ANTAGONIST', 'description': '...             None
# 2449  {'action_type': 'ANTAGONIST', 'description': '...             None
# 2450                                               None             None
# 2451                                               None             None
#
#       activity_id                                activity_properties  \
# 0           32544                                                 []
# 1           33756                                                 []
# 2           38634                                                 []
# 3           38643                                                 []
# 4           39754                                                 []
# ...           ...                                                ...
# 2447     25631924                                                 []
# 2448     25631925                                                 []
# 2449     25631926                                                 []
# 2450     25778419  [{'comments': None, 'relation': '=', 'result_f...
# 2451     25787567  [{'comments': None, 'relation': None, 'result_...
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL749749  Binding affinity on cloned opioid receptor mu ...
# 1       CHEMBL749749  Binding affinity on cloned opioid receptor mu ...
# 2       CHEMBL749749  Binding affinity on cloned opioid receptor mu ...
# 3       CHEMBL749749  Binding affinity on cloned opioid receptor mu ...
# 4       CHEMBL749749  Binding affinity on cloned opioid receptor mu ...
# ...              ...                                                ...
# 2447   CHEMBL5365899  Antagonist activity at human mu opioid recepto...
# 2448   CHEMBL5365899  Antagonist activity at human mu opioid recepto...
# 2449   CHEMBL5365899  Antagonist activity at human mu opioid recepto...
# 2450   CHEMBL5465602  Selectivity interaction (BET inhibitor selecti...
# 2451   CHEMBL5474455  Selectivity interaction (Opioid Mu GTPgS agoni...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 2447          F                    None                   None  BAO_0000190
# 2448          F                    None                   None  BAO_0000190
# 2449          F                    None                   None  BAO_0000190
# 2450          B                    None                   None  BAO_0000190
# 2451          B                    None                   None  BAO_0000190
#
#       ... target_organism    target_pref_name target_tax_id text_value  toid  \
# 0     ...    Homo sapiens  Mu opioid receptor          9606       None  None
# 1     ...    Homo sapiens  Mu opioid receptor          9606       None  None
# 2     ...    Homo sapiens  Mu opioid receptor          9606       None  None
# 3     ...    Homo sapiens  Mu opioid receptor          9606       None  None
# 4     ...    Homo sapiens  Mu opioid receptor          9606       None  None
# ...   ...             ...                 ...           ...        ...   ...
# 2447  ...    Homo sapiens  Mu opioid receptor          9606       None  None
# 2448  ...    Homo sapiens  Mu opioid receptor          9606       None  None
# 2449  ...    Homo sapiens  Mu opioid receptor          9606       None  None
# 2450  ...    Homo sapiens  Mu opioid receptor          9606       None  None
# 2451  ...    Homo sapiens  Mu opioid receptor          9606       None  None
#
#       type units    uo_units upper_value    value
# 0     IC50    nM  UO_0000065        None   5250.0
# 1     IC50    nM  UO_0000065        None   3480.0
# 2     IC50    nM  UO_0000065        None    320.0
# 3     IC50    nM  UO_0000065        None   4130.0
# 4     IC50    nM  UO_0000065        None  10000.0
# ...    ...   ...         ...         ...      ...
# 2447  IC50    nM  UO_0000065        None    210.0
# 2448  IC50    nM  UO_0000065        None    110.0
# 2449  IC50    nM  UO_0000065        None     29.0
# 2450  IC50    uM  UO_0000065        None    100.0
# 2451  IC50    uM  UO_0000065        None     30.0
#
# [1509 rows x 46 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 1301

# %%
df2_nr = df2.drop_duplicates(subset="canonical_smiles", keep="first").reset_index(drop=True)

# %%
df2_nr
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1296  {'action_type': 'ANTAGONIST', 'description': '...             None
# 1297  {'action_type': 'ANTAGONIST', 'description': '...             None
# 1298  {'action_type': 'ANTAGONIST', 'description': '...             None
# 1299                                               None             None
# 1300                                               None             None
#
#       activity_id                                activity_properties  \
# 0           32544                                                 []
# 1           33756                                                 []
# 2           38634                                                 []
# 3           38643                                                 []
# 4           39754                                                 []
# ...           ...                                                ...
# 1296     25631924                                                 []
# 1297     25631925                                                 []
# 1298     25631926                                                 []
# 1299     25778419  [{'comments': None, 'relation': '=', 'result_f...
# 1300     25787567  [{'comments': None, 'relation': None, 'result_...
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL749749  Binding affinity on cloned opioid receptor mu ...
# 1       CHEMBL749749  Binding affinity on cloned opioid receptor mu ...
# 2       CHEMBL749749  Binding affinity on cloned opioid receptor mu ...
# 3       CHEMBL749749  Binding affinity on cloned opioid receptor mu ...
# 4       CHEMBL749749  Binding affinity on cloned opioid receptor mu ...
# ...              ...                                                ...
# 1296   CHEMBL5365899  Antagonist activity at human mu opioid recepto...
# 1297   CHEMBL5365899  Antagonist activity at human mu opioid recepto...
# 1298   CHEMBL5365899  Antagonist activity at human mu opioid recepto...
# 1299   CHEMBL5465602  Selectivity interaction (BET inhibitor selecti...
# 1300   CHEMBL5474455  Selectivity interaction (Opioid Mu GTPgS agoni...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 1296          F                    None                   None  BAO_0000190
# 1297          F                    None                   None  BAO_0000190
# 1298          F                    None                   None  BAO_0000190
# 1299          B                    None                   None  BAO_0000190
# 1300          B                    None                   None  BAO_0000190
#
#       ... target_organism    target_pref_name target_tax_id text_value  toid  \
# 0     ...    Homo sapiens  Mu opioid receptor          9606       None  None
# 1     ...    Homo sapiens  Mu opioid receptor          9606       None  None
# 2     ...    Homo sapiens  Mu opioid receptor          9606       None  None
# 3     ...    Homo sapiens  Mu opioid receptor          9606       None  None
# 4     ...    Homo sapiens  Mu opioid receptor          9606       None  None
# ...   ...             ...                 ...           ...        ...   ...
# 1296  ...    Homo sapiens  Mu opioid receptor          9606       None  None
# 1297  ...    Homo sapiens  Mu opioid receptor          9606       None  None
# 1298  ...    Homo sapiens  Mu opioid receptor          9606       None  None
# 1299  ...    Homo sapiens  Mu opioid receptor          9606       None  None
# 1300  ...    Homo sapiens  Mu opioid receptor          9606       None  None
#
#       type units    uo_units upper_value    value
# 0     IC50    nM  UO_0000065        None   5250.0
# 1     IC50    nM  UO_0000065        None   3480.0
# 2     IC50    nM  UO_0000065        None    320.0
# 3     IC50    nM  UO_0000065        None   4130.0
# 4     IC50    nM  UO_0000065        None  10000.0
# ...    ...   ...         ...         ...      ...
# 1296  IC50    nM  UO_0000065        None    210.0
# 1297  IC50    nM  UO_0000065        None    110.0
# 1298  IC50    nM  UO_0000065        None     29.0
# 1299  IC50    uM  UO_0000065        None    100.0
# 1300  IC50    uM  UO_0000065        None     30.0
#
# [1301 rows x 46 columns]

# %%
df2_nr.columns
# Out:
# Index(['action_type', 'activity_comment', 'activity_id', 'activity_properties',
#        'assay_chembl_id', 'assay_description', 'assay_type',
#        'assay_variant_accession', 'assay_variant_mutation', 'bao_endpoint',
#        'bao_format', 'bao_label', 'canonical_smiles', 'data_validity_comment',
#        'data_validity_description', 'document_chembl_id', 'document_journal',
#        'document_year', 'ligand_efficiency', 'molecule_chembl_id',
#        'molecule_pref_name', 'parent_molecule_chembl_id', 'pchembl_value',
#        'potential_duplicate', 'qudt_units', 'record_id', 'relation', 'src_id',
#        'standard_flag', 'standard_relation', 'standard_text_value',
#        'standard_type', 'standard_units', 'standard_upper_value',
#        'standard_value', 'target_chembl_id', 'target_organism',
#        'target_pref_name', 'target_tax_id', 'text_value', 'toid', 'type',
#        'units', 'uo_units', 'upper_value', 'value'],
#       dtype='object')

# %% [markdown]
# ## Data pre-processing of the bioactivity data
# #### Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL423694     CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2cccc(OC)c2)cc1
# 1          CHEMBL278078       CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2ccccc2OC)cc1
# 2           CHEMBL13470  C=CCN1C[C@H](C)N([C@H](c2ccc(C(=O)N(CC)CC)cc2)...
# 3          CHEMBL127802   CCCCN1CCC(=C(c2ccccc2)c2ccc(C(=O)N(CC)CC)cc2)CC1
# 4          CHEMBL126946      CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2ccc(F)cc2)cc1
# ...                 ...                                                ...
# 1296      CHEMBL5429557  CN(C)[C@H](CNC(=O)[C@H]1C[C@]1(C)c1ccccc1)Cc1c...
# 1297      CHEMBL5397104  CN(C)[C@H](CNC(=O)[C@@H]1C[C@]1(C)c1ccccc1)Cc1...
# 1298      CHEMBL5414957  CN(C)[C@H](CNC(=O)[C@@H]1C[C@]1(C)c1ccccc1)Cc1...
# 1299      CHEMBL2017291  COc1cc2c(cc1-c1c(C)noc1C)ncc1[nH]c(=O)n([C@H](...
# 1300      CHEMBL3643413  CCC(=O)N1CC[C@H](Nc2ncnc3c2CN(c2cnc(OC)c(C(F)(...
#
#      standard_value
# 0            5250.0
# 1            3480.0
# 2             320.0
# 3            4130.0
# 4           10000.0
# ...             ...
# 1296          210.0
# 1297          110.0
# 1298           29.0
# 1299       100000.0
# 1300        30000.0
#
# [1301 rows x 3 columns]

# %% [markdown]
# ## Labeling compounds as either being active, inactive or intermediate
# #### The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be active while those greater than 10,000 nM will be considered to be inactive. As for those values in between 1,000 and 10,000 nM will be referred to as intermediate.

# %%
bioactivity_threshold = []
for i in df3.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df3, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL423694     CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2cccc(OC)c2)cc1
# 1          CHEMBL278078       CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2ccccc2OC)cc1
# 2           CHEMBL13470  C=CCN1C[C@H](C)N([C@H](c2ccc(C(=O)N(CC)CC)cc2)...
# 3          CHEMBL127802   CCCCN1CCC(=C(c2ccccc2)c2ccc(C(=O)N(CC)CC)cc2)CC1
# 4          CHEMBL126946      CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2ccc(F)cc2)cc1
# ...                 ...                                                ...
# 1296      CHEMBL5429557  CN(C)[C@H](CNC(=O)[C@H]1C[C@]1(C)c1ccccc1)Cc1c...
# 1297      CHEMBL5397104  CN(C)[C@H](CNC(=O)[C@@H]1C[C@]1(C)c1ccccc1)Cc1...
# 1298      CHEMBL5414957  CN(C)[C@H](CNC(=O)[C@@H]1C[C@]1(C)c1ccccc1)Cc1...
# 1299      CHEMBL2017291  COc1cc2c(cc1-c1c(C)noc1C)ncc1[nH]c(=O)n([C@H](...
# 1300      CHEMBL3643413  CCC(=O)N1CC[C@H](Nc2ncnc3c2CN(c2cnc(OC)c(C(F)(...
#
#      standard_value         class
# 0            5250.0  intermediate
# 1            3480.0  intermediate
# 2             320.0        active
# 3            4130.0  intermediate
# 4           10000.0      inactive
# ...             ...           ...
# 1296          210.0        active
# 1297          110.0        active
# 1298           29.0        active
# 1299       100000.0      inactive
# 1300        30000.0      inactive
#
# [1301 rows x 4 columns]

# %%
df5.to_csv('opioid receptor_03_bioactivity_data_curated.csv', index=False)

# %%
df = pd.read_csv(r"C:\Users\manoj\OneDrive\Desktop\opioid receptor\opioid receptor_03_bioactivity_data_curated.csv")
df
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL423694     CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2cccc(OC)c2)cc1
# 1          CHEMBL278078       CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2ccccc2OC)cc1
# 2           CHEMBL13470  C=CCN1C[C@H](C)N([C@H](c2ccc(C(=O)N(CC)CC)cc2)...
# 3          CHEMBL127802   CCCCN1CCC(=C(c2ccccc2)c2ccc(C(=O)N(CC)CC)cc2)CC1
# 4          CHEMBL126946      CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2ccc(F)cc2)cc1
# ...                 ...                                                ...
# 1296      CHEMBL5429557  CN(C)[C@H](CNC(=O)[C@H]1C[C@]1(C)c1ccccc1)Cc1c...
# 1297      CHEMBL5397104  CN(C)[C@H](CNC(=O)[C@@H]1C[C@]1(C)c1ccccc1)Cc1...
# 1298      CHEMBL5414957  CN(C)[C@H](CNC(=O)[C@@H]1C[C@]1(C)c1ccccc1)Cc1...
# 1299      CHEMBL2017291  COc1cc2c(cc1-c1c(C)noc1C)ncc1[nH]c(=O)n([C@H](...
# 1300      CHEMBL3643413  CCC(=O)N1CC[C@H](Nc2ncnc3c2CN(c2cnc(OC)c(C(F)(...
#
#       standard_value         class
# 0             5250.0  intermediate
# 1             3480.0  intermediate
# 2              320.0        active
# 3             4130.0  intermediate
# 4            10000.0      inactive
# ...              ...           ...
# 1296           210.0        active
# 1297           110.0        active
# 1298            29.0        active
# 1299        100000.0      inactive
# 1300         30000.0      inactive
#
# [1301 rows x 4 columns]

# %%
df_no_smiles = df.drop(columns='canonical_smiles')

# %%
smiles = []

for i in df.canonical_smiles.tolist():
  cpd = str(i).split('.')
  cpd_longest = max(cpd, key = len)
  smiles.append(cpd_longest)

smiles = pd.Series(smiles, name = 'canonical_smiles')

# %%
df_clean_smiles = pd.concat([df_no_smiles,smiles], axis=1)
df_clean_smiles
# Out:
#      molecule_chembl_id  standard_value         class  \
# 0          CHEMBL423694          5250.0  intermediate
# 1          CHEMBL278078          3480.0  intermediate
# 2           CHEMBL13470           320.0        active
# 3          CHEMBL127802          4130.0  intermediate
# 4          CHEMBL126946         10000.0      inactive
# ...                 ...             ...           ...
# 1296      CHEMBL5429557           210.0        active
# 1297      CHEMBL5397104           110.0        active
# 1298      CHEMBL5414957            29.0        active
# 1299      CHEMBL2017291        100000.0      inactive
# 1300      CHEMBL3643413         30000.0      inactive
#
#                                        canonical_smiles
# 0        CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2cccc(OC)c2)cc1
# 1          CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2ccccc2OC)cc1
# 2     C=CCN1C[C@H](C)N([C@H](c2ccc(C(=O)N(CC)CC)cc2)...
# 3      CCCCN1CCC(=C(c2ccccc2)c2ccc(C(=O)N(CC)CC)cc2)CC1
# 4         CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2ccc(F)cc2)cc1
# ...                                                 ...
# 1296  CN(C)[C@H](CNC(=O)[C@H]1C[C@]1(C)c1ccccc1)Cc1c...
# 1297  CN(C)[C@H](CNC(=O)[C@@H]1C[C@]1(C)c1ccccc1)Cc1...
# 1298  CN(C)[C@H](CNC(=O)[C@@H]1C[C@]1(C)c1ccccc1)Cc1...
# 1299  COc1cc2c(cc1-c1c(C)noc1C)ncc1[nH]c(=O)n([C@H](...
# 1300  CCC(=O)N1CC[C@H](Nc2ncnc3c2CN(c2cnc(OC)c(C(F)(...
#
# [1301 rows x 4 columns]

# %% [markdown]
# ### Calculate Lipinski descriptors
# #### Christopher Lipinski, a scientist at Pfizer, came up with a set of rule-of-thumb for evaluating the druglikeness of compounds. Such druglikeness is based on the Absorption, Distribution, Metabolism and Excretion (ADME) that is also known as the pharmacokinetic profile. Lipinski analyzed all orally active FDA-approved drugs in the formulation of what is to be known as the Rule-of-Five or Lipinski's Rule.
#
# The Lipinski's Rule stated the following:
#
# Molecular weight < 500 Dalton
# Octanol-water partition coefficient (LogP) < 5
# Hydrogen bond donors < 5
# Hydrogen bond acceptors < 10

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

# %% [markdown]
# ### Calculate descriptors

# %%
# Inspired by: https://codeocean.com/explore/capsules?query=tag:data-curation

def lipinski(smiles, verbose=False):

    moldata= []
    for elem in smiles:
        mol=Chem.MolFromSmiles(elem) 
        moldata.append(mol)
       
    baseData= np.arange(1,1)
    i=0  
    for mol in moldata:        
       
        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)
           
        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])   
    
        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
        i=i+1      
    
    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]   
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)
    
    return descriptors

# %%
df_lipinski = lipinski(df_clean_smiles.canonical_smiles)
df_lipinski
# Out:
#            MW     LogP  NumHDonors  NumHAcceptors
# 0     378.516  4.36250         1.0            3.0
# 1     378.516  4.36250         1.0            3.0
# 2     449.639  4.84720         0.0            4.0
# 3     404.598  5.86640         0.0            2.0
# 4     366.480  4.49300         1.0            2.0
# ...       ...      ...         ...            ...
# 1296  352.478  2.95890         2.0            3.0
# 1297  352.478  2.95890         2.0            3.0
# 1298  386.923  3.61230         2.0            3.0
# 1299  415.453  4.16254         1.0            7.0
# 1300  450.465  2.88450         1.0            7.0
#
# [1301 rows x 4 columns]

# %% [markdown]
# ## Combine DataFrames

# %%
df_lipinski
# Out:
#            MW     LogP  NumHDonors  NumHAcceptors
# 0     378.516  4.36250         1.0            3.0
# 1     378.516  4.36250         1.0            3.0
# 2     449.639  4.84720         0.0            4.0
# 3     404.598  5.86640         0.0            2.0
# 4     366.480  4.49300         1.0            2.0
# ...       ...      ...         ...            ...
# 1296  352.478  2.95890         2.0            3.0
# 1297  352.478  2.95890         2.0            3.0
# 1298  386.923  3.61230         2.0            3.0
# 1299  415.453  4.16254         1.0            7.0
# 1300  450.465  2.88450         1.0            7.0
#
# [1301 rows x 4 columns]

# %%
df_lipinski.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1301 entries, 0 to 1300
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MW             1301 non-null   float64
#  1   LogP           1301 non-null   float64
#  2   NumHDonors     1301 non-null   float64
#  3   NumHAcceptors  1301 non-null   float64
# dtypes: float64(4)
# memory usage: 40.8 KB

# %%
df_lipinski.describe()
# Out:
#                 MW         LogP   NumHDonors  NumHAcceptors
# count  1301.000000  1301.000000  1301.000000    1301.000000
# mean    460.980948     3.963422     2.023828       4.727902
# std     181.132768     1.958788     2.685611       2.663670
# min     115.220000    -8.073000     0.000000       1.000000
# 25%     365.433000     3.114900     1.000000       3.000000
# 50%     419.160000     3.950440     1.000000       4.000000
# 75%     496.604000     4.958700     2.000000       6.000000
# max    1904.213000    12.487600    29.000000      26.000000

# %%
df
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL423694     CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2cccc(OC)c2)cc1
# 1          CHEMBL278078       CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2ccccc2OC)cc1
# 2           CHEMBL13470  C=CCN1C[C@H](C)N([C@H](c2ccc(C(=O)N(CC)CC)cc2)...
# 3          CHEMBL127802   CCCCN1CCC(=C(c2ccccc2)c2ccc(C(=O)N(CC)CC)cc2)CC1
# 4          CHEMBL126946      CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2ccc(F)cc2)cc1
# ...                 ...                                                ...
# 1296      CHEMBL5429557  CN(C)[C@H](CNC(=O)[C@H]1C[C@]1(C)c1ccccc1)Cc1c...
# 1297      CHEMBL5397104  CN(C)[C@H](CNC(=O)[C@@H]1C[C@]1(C)c1ccccc1)Cc1...
# 1298      CHEMBL5414957  CN(C)[C@H](CNC(=O)[C@@H]1C[C@]1(C)c1ccccc1)Cc1...
# 1299      CHEMBL2017291  COc1cc2c(cc1-c1c(C)noc1C)ncc1[nH]c(=O)n([C@H](...
# 1300      CHEMBL3643413  CCC(=O)N1CC[C@H](Nc2ncnc3c2CN(c2cnc(OC)c(C(F)(...
#
#       standard_value         class
# 0             5250.0  intermediate
# 1             3480.0  intermediate
# 2              320.0        active
# 3             4130.0  intermediate
# 4            10000.0      inactive
# ...              ...           ...
# 1296           210.0        active
# 1297           110.0        active
# 1298            29.0        active
# 1299        100000.0      inactive
# 1300         30000.0      inactive
#
# [1301 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1301 entries, 0 to 1300
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   molecule_chembl_id  1301 non-null   object
#  1   canonical_smiles    1301 non-null   object
#  2   standard_value      1301 non-null   float64
#  3   class               1301 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 40.8+ KB

# %%
df.describe()
# Out:
#        standard_value
# count    1.301000e+03
# mean     9.888287e+03
# std      6.473024e+04
# min     -2.810000e+04
# 25%      5.800000e+01
# 50%      1.100000e+03
# 75%      9.600000e+03
# max      2.000000e+06

# %% [markdown]
# #### combine the 2 DataFrame

# %%
df_combined = pd.concat([df,df_lipinski], axis=1)

# %%
df_combined
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL423694     CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2cccc(OC)c2)cc1
# 1          CHEMBL278078       CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2ccccc2OC)cc1
# 2           CHEMBL13470  C=CCN1C[C@H](C)N([C@H](c2ccc(C(=O)N(CC)CC)cc2)...
# 3          CHEMBL127802   CCCCN1CCC(=C(c2ccccc2)c2ccc(C(=O)N(CC)CC)cc2)CC1
# 4          CHEMBL126946      CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2ccc(F)cc2)cc1
# ...                 ...                                                ...
# 1296      CHEMBL5429557  CN(C)[C@H](CNC(=O)[C@H]1C[C@]1(C)c1ccccc1)Cc1c...
# 1297      CHEMBL5397104  CN(C)[C@H](CNC(=O)[C@@H]1C[C@]1(C)c1ccccc1)Cc1...
# 1298      CHEMBL5414957  CN(C)[C@H](CNC(=O)[C@@H]1C[C@]1(C)c1ccccc1)Cc1...
# 1299      CHEMBL2017291  COc1cc2c(cc1-c1c(C)noc1C)ncc1[nH]c(=O)n([C@H](...
# 1300      CHEMBL3643413  CCC(=O)N1CC[C@H](Nc2ncnc3c2CN(c2cnc(OC)c(C(F)(...
#
#       standard_value         class       MW     LogP  NumHDonors  \
# 0             5250.0  intermediate  378.516  4.36250         1.0
# 1             3480.0  intermediate  378.516  4.36250         1.0
# 2              320.0        active  449.639  4.84720         0.0
# 3             4130.0  intermediate  404.598  5.86640         0.0
# 4            10000.0      inactive  366.480  4.49300         1.0
# ...              ...           ...      ...      ...         ...
# 1296           210.0        active  352.478  2.95890         2.0
# 1297           110.0        active  352.478  2.95890         2.0
# 1298            29.0        active  386.923  3.61230         2.0
# 1299        100000.0      inactive  415.453  4.16254         1.0
# 1300         30000.0      inactive  450.465  2.88450         1.0
#
#       NumHAcceptors
# 0               3.0
# 1               3.0
# 2               4.0
# 3               2.0
# 4               2.0
# ...             ...
# 1296            3.0
# 1297            3.0
# 1298            3.0
# 1299            7.0
# 1300            7.0
#
# [1301 rows x 8 columns]

# %% [markdown]
# 1301 rows × 8 columns

# %%
df_combined.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL423694     CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2cccc(OC)c2)cc1
# 1       CHEMBL278078       CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2ccccc2OC)cc1
# 2        CHEMBL13470  C=CCN1C[C@H](C)N([C@H](c2ccc(C(=O)N(CC)CC)cc2)...
# 3       CHEMBL127802   CCCCN1CCC(=C(c2ccccc2)c2ccc(C(=O)N(CC)CC)cc2)CC1
# 4       CHEMBL126946      CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2ccc(F)cc2)cc1
#
#    standard_value         class       MW    LogP  NumHDonors  NumHAcceptors
# 0          5250.0  intermediate  378.516  4.3625         1.0            3.0
# 1          3480.0  intermediate  378.516  4.3625         1.0            3.0
# 2           320.0        active  449.639  4.8472         0.0            4.0
# 3          4130.0  intermediate  404.598  5.8664         0.0            2.0
# 4         10000.0      inactive  366.480  4.4930         1.0            2.0

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1301 entries, 0 to 1300
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   molecule_chembl_id  1301 non-null   object
#  1   canonical_smiles    1301 non-null   object
#  2   standard_value      1301 non-null   float64
#  3   class               1301 non-null   object
#  4   MW                  1301 non-null   float64
#  5   LogP                1301 non-null   float64
#  6   NumHDonors          1301 non-null   float64
#  7   NumHAcceptors       1301 non-null   float64
# dtypes: float64(5), object(3)
# memory usage: 81.4+ KB

# %%
df_combined.describe()
# Out:
#        standard_value           MW         LogP   NumHDonors  NumHAcceptors
# count    1.301000e+03  1301.000000  1301.000000  1301.000000    1301.000000
# mean     9.888287e+03   460.980948     3.963422     2.023828       4.727902
# std      6.473024e+04   181.132768     1.958788     2.685611       2.663670
# min     -2.810000e+04   115.220000    -8.073000     0.000000       1.000000
# 25%      5.800000e+01   365.433000     3.114900     1.000000       3.000000
# 50%      1.100000e+03   419.160000     3.950440     1.000000       4.000000
# 75%      9.600000e+03   496.604000     4.958700     2.000000       6.000000
# max      2.000000e+06  1904.213000    12.487600    29.000000      26.000000

# %% [markdown]
# ## Convert IC50 to pIC50
# To allow IC50 data to be more uniformly distributed, we will convert IC50 to the negative logarithmic scale which is essentially -log10(IC50).
#
# This custom function pIC50() will accept a DataFrame as input and will:
#
# Take the IC50 values from the standard_value column and converts it from nM to M by multiplying the value by 10
# Take the molar value and apply -log10
# Delete the standard_value column and create a new pIC50 column

# %%
# https://github.com/chaninlab/estrogen-receptor-alpha-qsar/blob/master/02_ER_alpha_RO5.ipynb

import numpy as np

def pIC50(input):
    pIC50 = []

    for i in input['standard_value_norm']:
        molar = i*(10**-9) # Converts nM to M
        pIC50.append(-np.log10(molar))

    input['pIC50'] = pIC50
    x = input.drop('standard_value_norm', 1)
        
    return x

# %%
df_combined.standard_value.describe()
# Out:
# count    1.301000e+03
# mean     9.888287e+03
# std      6.473024e+04
# min     -2.810000e+04
# 25%      5.800000e+01
# 50%      1.100000e+03
# 75%      9.600000e+03
# max      2.000000e+06
# Name: standard_value, dtype: float64

# %%
-np.log10( (10**-9)* 100000000 )
# Out:
# 1.0

# %%
-np.log10( (10**-9)* 10000000000 )
# Out:
# -1.0

# %%
def norm_value(input):
    norm = []

    for i in input['standard_value']:
        if i > 100000000:
          i = 100000000
        norm.append(i)

    input['standard_value_norm'] = norm
    x = input.drop('standard_value', axis=1)
        
    return x

# %% [raw]
# We will first apply the norm_value() function so that the values in the standard_value column is normalized.

# %%
df_norm = norm_value(df_combined)
df_norm
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL423694     CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2cccc(OC)c2)cc1
# 1          CHEMBL278078       CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2ccccc2OC)cc1
# 2           CHEMBL13470  C=CCN1C[C@H](C)N([C@H](c2ccc(C(=O)N(CC)CC)cc2)...
# 3          CHEMBL127802   CCCCN1CCC(=C(c2ccccc2)c2ccc(C(=O)N(CC)CC)cc2)CC1
# 4          CHEMBL126946      CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2ccc(F)cc2)cc1
# ...                 ...                                                ...
# 1296      CHEMBL5429557  CN(C)[C@H](CNC(=O)[C@H]1C[C@]1(C)c1ccccc1)Cc1c...
# 1297      CHEMBL5397104  CN(C)[C@H](CNC(=O)[C@@H]1C[C@]1(C)c1ccccc1)Cc1...
# 1298      CHEMBL5414957  CN(C)[C@H](CNC(=O)[C@@H]1C[C@]1(C)c1ccccc1)Cc1...
# 1299      CHEMBL2017291  COc1cc2c(cc1-c1c(C)noc1C)ncc1[nH]c(=O)n([C@H](...
# 1300      CHEMBL3643413  CCC(=O)N1CC[C@H](Nc2ncnc3c2CN(c2cnc(OC)c(C(F)(...
#
#              class       MW     LogP  NumHDonors  NumHAcceptors  \
# 0     intermediate  378.516  4.36250         1.0            3.0
# 1     intermediate  378.516  4.36250         1.0            3.0
# 2           active  449.639  4.84720         0.0            4.0
# 3     intermediate  404.598  5.86640         0.0            2.0
# 4         inactive  366.480  4.49300         1.0            2.0
# ...            ...      ...      ...         ...            ...
# 1296        active  352.478  2.95890         2.0            3.0
# 1297        active  352.478  2.95890         2.0            3.0
# 1298        active  386.923  3.61230         2.0            3.0
# 1299      inactive  415.453  4.16254         1.0            7.0
# 1300      inactive  450.465  2.88450         1.0            7.0
#
#       standard_value_norm
# 0                  5250.0
# 1                  3480.0
# 2                   320.0
# 3                  4130.0
# 4                 10000.0
# ...                   ...
# 1296                210.0
# 1297                110.0
# 1298                 29.0
# 1299             100000.0
# 1300              30000.0
#
# [1301 rows x 8 columns]

# %%
df_norm.standard_value_norm
# Out:
# 0         5250.0
# 1         3480.0
# 2          320.0
# 3         4130.0
# 4        10000.0
#           ...
# 1296       210.0
# 1297       110.0
# 1298        29.0
# 1299    100000.0
# 1300     30000.0
# Name: standard_value_norm, Length: 1301, dtype: float64

# %%
df_norm.standard_value_norm.describe()
# Out:
# count    1.301000e+03
# mean     9.888287e+03
# std      6.473024e+04
# min     -2.810000e+04
# 25%      5.800000e+01
# 50%      1.100000e+03
# 75%      9.600000e+03
# max      2.000000e+06
# Name: standard_value_norm, dtype: float64

# %%
df_final = df_norm.drop('standard_value_norm', axis=1)
df_final
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL423694     CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2cccc(OC)c2)cc1
# 1          CHEMBL278078       CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2ccccc2OC)cc1
# 2           CHEMBL13470  C=CCN1C[C@H](C)N([C@H](c2ccc(C(=O)N(CC)CC)cc2)...
# 3          CHEMBL127802   CCCCN1CCC(=C(c2ccccc2)c2ccc(C(=O)N(CC)CC)cc2)CC1
# 4          CHEMBL126946      CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2ccc(F)cc2)cc1
# ...                 ...                                                ...
# 1296      CHEMBL5429557  CN(C)[C@H](CNC(=O)[C@H]1C[C@]1(C)c1ccccc1)Cc1c...
# 1297      CHEMBL5397104  CN(C)[C@H](CNC(=O)[C@@H]1C[C@]1(C)c1ccccc1)Cc1...
# 1298      CHEMBL5414957  CN(C)[C@H](CNC(=O)[C@@H]1C[C@]1(C)c1ccccc1)Cc1...
# 1299      CHEMBL2017291  COc1cc2c(cc1-c1c(C)noc1C)ncc1[nH]c(=O)n([C@H](...
# 1300      CHEMBL3643413  CCC(=O)N1CC[C@H](Nc2ncnc3c2CN(c2cnc(OC)c(C(F)(...
#
#              class       MW     LogP  NumHDonors  NumHAcceptors     pIC50
# 0     intermediate  378.516  4.36250         1.0            3.0  5.279841
# 1     intermediate  378.516  4.36250         1.0            3.0  5.458421
# 2           active  449.639  4.84720         0.0            4.0  6.494850
# 3     intermediate  404.598  5.86640         0.0            2.0  5.384050
# 4         inactive  366.480  4.49300         1.0            2.0  5.000000
# ...            ...      ...      ...         ...            ...       ...
# 1296        active  352.478  2.95890         2.0            3.0  6.677781
# 1297        active  352.478  2.95890         2.0            3.0  6.958607
# 1298        active  386.923  3.61230         2.0            3.0  7.537602
# 1299      inactive  415.453  4.16254         1.0            7.0  4.000000
# 1300      inactive  450.465  2.88450         1.0            7.0  4.522879
#
# [1301 rows x 8 columns]

# %%
df_final.pIC50.describe()
# Out:
# count    1300.000000
# mean        6.223332
# std         1.394669
# min         2.698970
# 25%         5.017729
# 50%         5.958607
# 75%         7.236572
# max        10.903090
# Name: pIC50, dtype: float64

# %% [markdown]
# ## Removing the 'intermediate' bioactivity class
# ### Here, we will be removing the intermediate class from our data set.

# %%
df_2class = df_final[df_final["class"]  != 'intermediate']
df_2class
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 2           CHEMBL13470  C=CCN1C[C@H](C)N([C@H](c2ccc(C(=O)N(CC)CC)cc2)...
# 4          CHEMBL126946      CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2ccc(F)cc2)cc1
# 8          CHEMBL338089  CCN(CC)C(=O)c1ccc(C(=C2CCN(c3ccccc3)CC2)c2cccc...
# 11         CHEMBL126842      CCN(CC)C(=O)c1ccc(C(=C2CCN(C)CC2)c2ccccc2)cc1
# 17         CHEMBL129034   CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2cccc3ccccc23)cc1
# ...                 ...                                                ...
# 1296      CHEMBL5429557  CN(C)[C@H](CNC(=O)[C@H]1C[C@]1(C)c1ccccc1)Cc1c...
# 1297      CHEMBL5397104  CN(C)[C@H](CNC(=O)[C@@H]1C[C@]1(C)c1ccccc1)Cc1...
# 1298      CHEMBL5414957  CN(C)[C@H](CNC(=O)[C@@H]1C[C@]1(C)c1ccccc1)Cc1...
# 1299      CHEMBL2017291  COc1cc2c(cc1-c1c(C)noc1C)ncc1[nH]c(=O)n([C@H](...
# 1300      CHEMBL3643413  CCC(=O)N1CC[C@H](Nc2ncnc3c2CN(c2cnc(OC)c(C(F)(...
#
#          class       MW     LogP  NumHDonors  NumHAcceptors     pIC50
# 2       active  449.639  4.84720         0.0            4.0  6.494850
# 4     inactive  366.480  4.49300         1.0            2.0  5.000000
# 8     inactive  424.588  6.27090         0.0            2.0  5.000000
# 11    inactive  362.517  4.69610         0.0            2.0  5.000000
# 17      active  398.550  5.50710         1.0            2.0  6.087778
# ...        ...      ...      ...         ...            ...       ...
# 1296    active  352.478  2.95890         2.0            3.0  6.677781
# 1297    active  352.478  2.95890         2.0            3.0  6.958607
# 1298    active  386.923  3.61230         2.0            3.0  7.537602
# 1299  inactive  415.453  4.16254         1.0            7.0  4.000000
# 1300  inactive  450.465  2.88450         1.0            7.0  4.522879
#
# [956 rows x 8 columns]

# %%
df_2class.to_csv('opioid receptor_04_bioactivity_data_3class_pIC50.csv')

# %%
df_2class.columns
# Out:
# Index(['molecule_chembl_id', 'canonical_smiles', 'class', 'MW', 'LogP',
#        'NumHDonors', 'NumHAcceptors', 'pIC50'],
#       dtype='object')

# %% [markdown]
# ## Exploratory Data Analysis (Chemical Space Analysis) via Lipinski descriptors

# %%
import seaborn as sns
sns.set(style='ticks')
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 10))
numeric_columns = ['MW', 'LogP', 'NumHDonors', 'NumHAcceptors', 'pIC50']
for i, column in enumerate(numeric_columns, 1):
 plt.subplot(2, 3, i) # 2 rows and 3 columns for better layout
 sns.boxplot(df_2class[column],color='green') # kde=True for kernel density estimate
 plt.title(f'boxplot of {column}')
 plt.xlabel(column)
 plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Frequency of Bioactivity Classes

# %%
# Set figure size
plt.figure(figsize=(8, 6))
# Count plot with hue
sns.countplot(x='class', hue='class', data=df_2class, palette='viridis')
# Add labels and title
plt.xlabel('Bioactivity Class')
plt.ylabel('Frequency')
plt.title('Frequency of Bioactivity Classes')
# Show plot
plt.show()

# %%
sns.pairplot(df_2class, vars=['NumHDonors', 'NumHAcceptors'], hue='class', palette='colorblind')
# Show plot
plt.show()

# %%
sns.pairplot(df_2class, hue='class', palette='dark')
# Show plot
plt.show()

# %%
numeric_columns = ['MW', 'LogP', 'NumHDonors', 'NumHAcceptors']
# Set figure size
plt.figure(figsize=(12, 10))
# Loop through numeric columns and create scatter plots
for i, column in enumerate(numeric_columns, 1):
 plt.subplot(2, 2, i) # 2 rows, 2 columns layout
 sns.scatterplot(x=df_2class[column], y=df_2class['pIC50'], hue=df_2class['class'], palette='colorblind')
 plt.title(f'Scatter Plot: pIC50 vs {column}')
 plt.xlabel(column)
 plt.ylabel('pIC50')
# Adjust layout
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x="class", data=df, )
plt.xlabel("Bioactivity Class")
plt.ylabel("Count")
plt.title("y Class Distribution")
plt.show()

# %%
plt.figure(figsize=(6.6, 5.6))
sns.scatterplot(x='MW', y='LogP', data=df_2class, hue='class', size='pIC50',palette='dark', edgecolor='black', alpha=0.7)
plt.xlabel('MW', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
plt.show()

# %%
plt.figure(figsize=(5.5, 5.5))
sns.boxplot(x = 'class', y = 'pIC50', data = df_2class, hue = 'class' ,palette = 'coolwarm')
plt.xlabel('class', fontsize=14, fontweight='bold')
# Out:
# Text(0.5, 0, 'class')

# %% [markdown]
# ### Statistical analysis | Mann-Whitney U Test

# %%
 # https://machinelearningmastery.com/nonparametric-statistical-significance-tests-in-python/
from numpy.random import seed
from scipy.stats import mannwhitneyu

def mannwhitney(descriptor, verbose=False):
    # Seed the random number generator for reproducibility
    seed(1)

    # Select relevant columns
    selection = [descriptor, 'class']
    df = df_2class[selection]

    # Split active and inactive classes
    active = df[df['class'] == 'active'][descriptor]
    inactive = df[df['class'] == 'inactive'][descriptor]

    # Perform Mann-Whitney U test
    stat, p = mannwhitneyu(active, inactive)

    # Interpret the result
    alpha = 0.05
    interpretation = 'Same distribution (fail to reject H0)' if p > alpha else 'Different distribution (reject H0)'

    # Store results in a DataFrame
    results = pd.DataFrame({
        'Descriptor': [descriptor],
        'Statistics': [stat],
        'p': [p],
        'alpha': [alpha],
        'Interpretation': [interpretation]
    })

    # Save results to CSV
    filename = f'mannwhitneyu_{descriptor}.csv'
    results.to_csv(filename, index=False)

    return results

# %%
mannwhitney('pIC50')
# Out:
#   Descriptor  Statistics   p  alpha                      Interpretation
# 0      pIC50         NaN NaN   0.05  Different distribution (reject H0)

# %% [markdown]
# ### MW

# %%
plt.figure(figsize=(5.5, 5.5))
sns.boxplot(x = 'class', y = 'MW', data = df_2class,hue = 'class' , palette = 'dark')
plt.xlabel('class', fontsize=14, fontweight='bold')
plt.ylabel('MW', fontsize=14, fontweight='bold')
# Out:
# Text(0, 0.5, 'MW')

# %%
mannwhitney('MW')
# Out:
#   Descriptor  Statistics         p  alpha  \
# 0         MW    108504.0  0.102365   0.05
#
#                           Interpretation
# 0  Same distribution (fail to reject H0)

# %% [markdown]
# ### LogP

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'LogP', data = df_2class,hue = 'class' , palette = 'magma')

plt.xlabel(' class', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')
# Out:
# Text(0, 0.5, 'LogP')

# %% [markdown]
# Statistical analysis | Mann-Whitney U Test

# %%
mannwhitney('LogP')
# Out:
#   Descriptor  Statistics         p  alpha  \
# 0       LogP    105271.5  0.405549   0.05
#
#                           Interpretation
# 0  Same distribution (fail to reject H0)

# %% [markdown]
# ## NumHDonors

# %%
plt.figure(figsize=(5.5, 5.5))
plt.figure(figsize=(5.5, 5.5))
sns.boxplot(x = 'class', y = 'NumHDonors', data = df_2class,hue = 'class' , palette = 'bright')
plt.xlabel(' class', fontsize=14, fontweight='bold')
plt.ylabel('NumHDonors', fontsize=14, fontweight='bold')
# Out:
# Text(0, 0.5, 'NumHDonors')

# %% [markdown]
# Statistical analysis | Mann-Whitney U Test

# %%
mannwhitney('NumHDonors')
# Out:
#    Descriptor  Statistics             p  alpha  \
# 0  NumHDonors    123067.0  4.233636e-08   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)

# %% [markdown]
# ## NumHAcceptors

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'NumHAcceptors', data = df_2class,hue = 'class' , palette = 'viridis')

plt.xlabel(' class', fontsize=14, fontweight='bold')
plt.ylabel('NumHAcceptors', fontsize=14, fontweight='bold')
# Out:
# Text(0, 0.5, 'NumHAcceptors')

# %% [markdown]
# Statistical analysis | Mann-Whitney U Test

# %%
mannwhitney('NumHAcceptors')
# Out:
#       Descriptor  Statistics         p  alpha  \
# 0  NumHAcceptors     91430.0  0.008387   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)

# %% [markdown]
# Box Plots pIC50 values Taking a look at pIC50 values, the actives and inactives displayed statistically significant difference, which is to be expected since threshold values (IC50 < 1,000 nM = Actives while IC50 > 10,000 nM = Inactives, corresponding to pIC50 > 6 = Actives and pIC50 < 5 = Inactives) were used to define actives and inactives.
#
# Lipinski's descriptors Of the 4 Lipinski's descriptors (MW, LogP, NumHDonors and NumHAcceptors), only NumHDonors and NumHAcceptors exhibited difference between the actives and inactives while the other descriptors ( only (MW, LogP shows statistically significant same difference between actives and inactives.

# %%
df3 = pd.read_csv(r"C:\Users\manoj\OneDrive\Desktop\opioid receptor\opioid receptor_04_bioactivity_data_3class_pIC50.csv")

# %%
df3
# Out:
#      Unnamed: 0 molecule_chembl_id  \
# 0             2        CHEMBL13470
# 1             4       CHEMBL126946
# 2             8       CHEMBL338089
# 3            11       CHEMBL126842
# 4            17       CHEMBL129034
# ..          ...                ...
# 951        1296      CHEMBL5429557
# 952        1297      CHEMBL5397104
# 953        1298      CHEMBL5414957
# 954        1299      CHEMBL2017291
# 955        1300      CHEMBL3643413
#
#                                       canonical_smiles     class       MW  \
# 0    C=CCN1C[C@H](C)N([C@H](c2ccc(C(=O)N(CC)CC)cc2)...    active  449.639
# 1        CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2ccc(F)cc2)cc1  inactive  366.480
# 2    CCN(CC)C(=O)c1ccc(C(=C2CCN(c3ccccc3)CC2)c2cccc...  inactive  424.588
# 3        CCN(CC)C(=O)c1ccc(C(=C2CCN(C)CC2)c2ccccc2)cc1  inactive  362.517
# 4     CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2cccc3ccccc23)cc1    active  398.550
# ..                                                 ...       ...      ...
# 951  CN(C)[C@H](CNC(=O)[C@H]1C[C@]1(C)c1ccccc1)Cc1c...    active  352.478
# 952  CN(C)[C@H](CNC(=O)[C@@H]1C[C@]1(C)c1ccccc1)Cc1...    active  352.478
# 953  CN(C)[C@H](CNC(=O)[C@@H]1C[C@]1(C)c1ccccc1)Cc1...    active  386.923
# 954  COc1cc2c(cc1-c1c(C)noc1C)ncc1[nH]c(=O)n([C@H](...  inactive  415.453
# 955  CCC(=O)N1CC[C@H](Nc2ncnc3c2CN(c2cnc(OC)c(C(F)(...  inactive  450.465
#
#         LogP  NumHDonors  NumHAcceptors     pIC50
# 0    4.84720         0.0            4.0  6.494850
# 1    4.49300         1.0            2.0  5.000000
# 2    6.27090         0.0            2.0  5.000000
# 3    4.69610         0.0            2.0  5.000000
# 4    5.50710         1.0            2.0  6.087778
# ..       ...         ...            ...       ...
# 951  2.95890         2.0            3.0  6.677781
# 952  2.95890         2.0            3.0  6.958607
# 953  3.61230         2.0            3.0  7.537602
# 954  4.16254         1.0            7.0  4.000000
# 955  2.88450         1.0            7.0  4.522879
#
# [956 rows x 9 columns]

# %%
df3.head()
# Out:
#    Unnamed: 0 molecule_chembl_id  \
# 0           2        CHEMBL13470
# 1           4       CHEMBL126946
# 2           8       CHEMBL338089
# 3          11       CHEMBL126842
# 4          17       CHEMBL129034
#
#                                     canonical_smiles     class       MW  \
# 0  C=CCN1C[C@H](C)N([C@H](c2ccc(C(=O)N(CC)CC)cc2)...    active  449.639
# 1      CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2ccc(F)cc2)cc1  inactive  366.480
# 2  CCN(CC)C(=O)c1ccc(C(=C2CCN(c3ccccc3)CC2)c2cccc...  inactive  424.588
# 3      CCN(CC)C(=O)c1ccc(C(=C2CCN(C)CC2)c2ccccc2)cc1  inactive  362.517
# 4   CCN(CC)C(=O)c1ccc(C(=C2CCNCC2)c2cccc3ccccc23)cc1    active  398.550
#
#      LogP  NumHDonors  NumHAcceptors     pIC50
# 0  4.8472         0.0            4.0  6.494850
# 1  4.4930         1.0            2.0  5.000000
# 2  6.2709         0.0            2.0  5.000000
# 3  4.6961         0.0            2.0  5.000000
# 4  5.5071         1.0            2.0  6.087778

# %%
df3.describe()
# Out:
#         Unnamed: 0           MW        LogP  NumHDonors  NumHAcceptors  \
# count   956.000000   956.000000  956.000000  956.000000     956.000000
# mean    677.293933   468.168969    3.875962    2.146444       4.843096
# std     364.371668   190.384243    2.008802    2.721929       2.745861
# min       2.000000   115.220000   -8.073000    0.000000       1.000000
# 25%     388.250000   362.469250    2.958900    1.000000       3.000000
# 50%     678.000000   423.794500    3.868980    1.000000       4.000000
# 75%     998.250000   507.030000    4.937450    2.000000       6.000000
# max    1300.000000  1904.213000   12.487600   29.000000      26.000000
#
#             pIC50
# count  955.000000
# mean     6.481876
# std      1.539089
# min      2.698970
# 25%      5.000000
# 50%      6.596879
# 75%      7.657577
# max     10.903090

# %%
selection = ['canonical_smiles','molecule_chembl_id']
df3_selection = df3[selection]
df3_selection.to_csv('molecule.smi', sep='\t', index=False, header=False)
